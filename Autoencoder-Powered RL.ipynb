# %% [markdown]
# # Building a Trading Bot for Pfizer Stock Data Using an Autoencoder and Reinforcement Learning

# %% [markdown]
# In this notebook, which is based on my previous project "Trading Bots for Pfizer Stock", I will use an autoencoder (AE) and reinforcement learning to create a bot for the trading of the Pfizer stock and observe its performance. I will compute important financial indicators for the stock data and use an autoencoder to obtain a compressed representation of these signals; the aim of using an AE is to eliminate noise and capture important trends from the indicators. I will then use this compressed representation as environment signals for the trading bot. I will also create a baseline model which includes all of the financial indicators, and I will compare the performance of both models.

# %%
#Importing the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import gym
import gym_anytrading
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines import A2C
from finta import TA
from gym_anytrading.envs import StocksEnv
from sklearn.preprocessing import StandardScaler
import random
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import BatchNormalization

# %%
#Reading in the data
PFE_data = pd.read_csv('C:/Users/chinm/Downloads/PFE_data.csv')

#Converting the date column to datetime and setting this to the index
PFE_data['Date'] = pd.to_datetime(PFE_data['Date'])
PFE_data = PFE_data.set_index('Date')

#Viewing the data
PFE_data.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2017-01-03  31.024668  31.309298  30.920303  31.309298  25.928759  23391844
# 2017-01-04  31.432638  31.641365  31.337761  31.584440  26.156618  22753963
# 2017-01-05  31.660341  31.963947  31.423149  31.888046  26.408049  21083584
# 2017-01-06  31.935484  31.973434  31.631880  31.764706  26.305901  18418228
# 2017-01-09  31.717268  31.944971  31.669828  31.755219  26.298042  21559886

# %%
#Creating a dataframe of important financial indicators
ind= pd.DataFrame() 
ind['SMA_10'] = TA.SMA(PFE_data,10) #10-day moving average
ind['SMA_50'] = TA.SMA(PFE_data,50) #50-day moving average
ind['SMA_200'] = TA.SMA(PFE_data,200) #200-day moving average
ind['RSI'] = TA.RSI(PFE_data) #Relative strength index
ind['MACD'] = TA.MACD(PFE_data)['MACD'] #Moving average convergence divergence
ind['OBV'] = TA.OBV(PFE_data) #On-balance volume
ind['BB'] = TA.BBWIDTH(PFE_data) #Bollinger bands width
ind['Stoch_K'] = TA.STOCH(PFE_data) #Stochastic oscillator K
ind['Stoch_D'] = TA.STOCHD(PFE_data) #Stochastic oscillator D

# %%
#Processing the dataframe
ind = ind.iloc[199:] #Beginning the dataframe at day 200, because we are working with 200-day MA
ind = ind.fillna(0) 
ind_norm = StandardScaler().fit_transform(ind)

# %%
#Building and fitting the autoencoder model

#Setting a seed for reproducibility
np.random.seed(2021)
tf.random.set_random_seed(2021)

X = ind_norm.copy()
inp_dim = X.shape[1]

#encoder
visible = Input(shape=(inp_dim,))
a = Dense(6)(visible)
a = BatchNormalization()(a)
a = LeakyReLU()(a)
#bottleneck
bottleneck = Dense(3)(a)
#decoder
b = Dense(6)(bottleneck)
b = BatchNormalization()(b)
b = LeakyReLU()(b)
#output
output = Dense(inp_dim, activation='linear')(b)

#Fitting the model
model = Model(inputs=visible, outputs=output)
model.compile(optimizer='adam', loss='mse')
history = model.fit(X, X, epochs=400, batch_size=50, verbose=2)
# Out:
# Train on 808 samples
# Epoch 1/400
# 808/808 - 2s - loss: 1.1367
# Epoch 2/400
# 808/808 - 0s - loss: 1.0469
# Epoch 3/400
# 808/808 - 0s - loss: 0.9816
# Epoch 4/400
# 808/808 - 0s - loss: 0.9262
# Epoch 5/400
# 808/808 - 0s - loss: 0.8841
# Epoch 6/400
# 808/808 - 0s - loss: 0.8367
# Epoch 7/400
# 808/808 - 0s - loss: 0.7895
# Epoch 8/400
# 808/808 - 0s - loss: 0.7471
# Epoch 9/400
# 808/808 - 0s - loss: 0.7090
# Epoch 10/400
# 808/808 - 0s - loss: 0.6705
# Epoch 11/400
# 808/808 - 0s - loss: 0.6333
# Epoch 12/400
# 808/808 - 0s - loss: 0.6060
# Epoch 13/400
# 808/808 - 0s - loss: 0.5738
# Epoch 14/400
# 808/808 - 0s - loss: 0.5465
# Epoch 15/400
# 808/808 - 0s - loss: 0.5181
# Epoch 16/400
# 808/808 - 0s - loss: 0.4976
# Epoch 17/400
# 808/808 - 0s - loss: 0.4726
# Epoch 18/400
# 808/808 - 0s - loss: 0.4562
# Epoch 19/400
# 808/808 - 0s - loss: 0.4288
# Epoch 20/400
# 808/808 - 0s - loss: 0.4009
# Epoch 21/400
# 808/808 - 0s - loss: 0.3869
# Epoch 22/400
# 808/808 - 0s - loss: 0.3701
# Epoch 23/400
# 808/808 - 0s - loss: 0.3504
# Epoch 24/400
# 808/808 - 0s - loss: 0.3366
# Epoch 25/400
# 808/808 - 0s - loss: 0.3247
# Epoch 26/400
# 808/808 - 0s - loss: 0.3119
# Epoch 27/400
# 808/808 - 0s - loss: 0.2985
# Epoch 28/400
# 808/808 - 0s - loss: 0.2946
# Epoch 29/400
# 808/808 - 0s - loss: 0.2827
# Epoch 30/400
# 808/808 - 0s - loss: 0.2723
# Epoch 31/400
# 808/808 - 0s - loss: 0.2688
# Epoch 32/400
# 808/808 - 0s - loss: 0.2618
# Epoch 33/400
# 808/808 - 0s - loss: 0.2545
# Epoch 34/400
# 808/808 - 0s - loss: 0.2570
# Epoch 35/400
# 808/808 - 0s - loss: 0.2496
# Epoch 36/400
# 808/808 - 0s - loss: 0.2390
# Epoch 37/400
# 808/808 - 0s - loss: 0.2473
# Epoch 38/400
# 808/808 - 0s - loss: 0.2436
# Epoch 39/400
# 808/808 - 0s - loss: 0.2421
# Epoch 40/400
# 808/808 - 0s - loss: 0.2306
# Epoch 41/400
# 808/808 - 0s - loss: 0.2445
# Epoch 42/400
# 808/808 - 0s - loss: 0.2323
# Epoch 43/400
# 808/808 - 0s - loss: 0.2339
# Epoch 44/400
# 808/808 - 0s - loss: 0.2256
# Epoch 45/400
# 808/808 - 0s - loss: 0.2237
# Epoch 46/400
# 808/808 - 0s - loss: 0.2244
# Epoch 47/400
# 808/808 - 0s - loss: 0.2294
# Epoch 48/400
# 808/808 - 0s - loss: 0.2258
# Epoch 49/400
# 808/808 - 0s - loss: 0.2151
# Epoch 50/400
# 808/808 - 0s - loss: 0.2237
# Epoch 51/400
# 808/808 - 0s - loss: 0.2128
# Epoch 52/400
# 808/808 - 0s - loss: 0.2304
# Epoch 53/400
# 808/808 - 0s - loss: 0.2163
# Epoch 54/400
# 808/808 - 0s - loss: 0.2195
# Epoch 55/400
# 808/808 - 0s - loss: 0.2185
# Epoch 56/400
# 808/808 - 0s - loss: 0.2098
# Epoch 57/400
# 808/808 - 0s - loss: 0.2133
# Epoch 58/400
# 808/808 - 0s - loss: 0.2080
# Epoch 59/400
# 808/808 - 0s - loss: 0.2149
# Epoch 60/400
# 808/808 - 0s - loss: 0.2042
# Epoch 61/400
# 808/808 - 0s - loss: 0.2106
# Epoch 62/400
# 808/808 - 0s - loss: 0.2029
# Epoch 63/400
# 808/808 - 0s - loss: 0.2134
# Epoch 64/400
# 808/808 - 0s - loss: 0.2025
# Epoch 65/400
# 808/808 - 0s - loss: 0.2131
# Epoch 66/400
# 808/808 - 0s - loss: 0.1988
# Epoch 67/400
# 808/808 - 0s - loss: 0.2133
# Epoch 68/400
# 808/808 - 0s - loss: 0.1970
# Epoch 69/400
# 808/808 - 0s - loss: 0.1984
# Epoch 70/400
# 808/808 - 0s - loss: 0.2110
# Epoch 71/400
# 808/808 - 0s - loss: 0.1988
# Epoch 72/400
# 808/808 - 0s - loss: 0.2013
# Epoch 73/400
# 808/808 - 0s - loss: 0.2073
# Epoch 74/400
# 808/808 - 0s - loss: 0.1959
# Epoch 75/400
# 808/808 - 0s - loss: 0.1982
# Epoch 76/400
# 808/808 - 0s - loss: 0.1981
# Epoch 77/400
# 808/808 - 0s - loss: 0.1956
# Epoch 78/400
# 808/808 - 0s - loss: 0.1973
# Epoch 79/400
# 808/808 - 0s - loss: 0.2011
# Epoch 80/400
# 808/808 - 0s - loss: 0.2049
# Epoch 81/400
# 808/808 - 0s - loss: 0.1925
# Epoch 82/400
# 808/808 - 0s - loss: 0.2009
# Epoch 83/400
# 808/808 - 0s - loss: 0.1931
# Epoch 84/400
# 808/808 - 0s - loss: 0.1966
# Epoch 85/400
# 808/808 - 0s - loss: 0.1952
# Epoch 86/400
# 808/808 - 0s - loss: 0.1852
# Epoch 87/400
# 808/808 - 0s - loss: 0.1902
# Epoch 88/400
# 808/808 - 0s - loss: 0.1974
# Epoch 89/400
# 808/808 - 0s - loss: 0.1959
# Epoch 90/400
# 808/808 - 0s - loss: 0.1910
# Epoch 91/400
# 808/808 - 0s - loss: 0.1950
# Epoch 92/400
# 808/808 - 0s - loss: 0.1955
# Epoch 93/400
# 808/808 - 0s - loss: 0.1962
# Epoch 94/400
# 808/808 - 0s - loss: 0.1856
# Epoch 95/400
# 808/808 - 0s - loss: 0.2007
# Epoch 96/400
# 808/808 - 0s - loss: 0.1916
# Epoch 97/400
# 808/808 - 0s - loss: 0.1858
# Epoch 98/400
# 808/808 - 0s - loss: 0.1831
# Epoch 99/400
# 808/808 - 0s - loss: 0.1917
# Epoch 100/400
# 808/808 - 0s - loss: 0.1869
# Epoch 101/400
# 808/808 - 0s - loss: 0.1870
# Epoch 102/400
# 808/808 - 0s - loss: 0.1868
# Epoch 103/400
# 808/808 - 0s - loss: 0.1866
# Epoch 104/400
# 808/808 - 0s - loss: 0.1731
# Epoch 105/400
# 808/808 - 0s - loss: 0.1831
# Epoch 106/400
# 808/808 - 0s - loss: 0.1802
# Epoch 107/400
# 808/808 - 0s - loss: 0.1867
# Epoch 108/400
# 808/808 - 0s - loss: 0.1850
# Epoch 109/400
# 808/808 - 0s - loss: 0.1841
# Epoch 110/400
# 808/808 - 0s - loss: 0.1819
# Epoch 111/400
# 808/808 - 0s - loss: 0.1827
# Epoch 112/400
# 808/808 - 0s - loss: 0.1776
# Epoch 113/400
# 808/808 - 0s - loss: 0.1833
# Epoch 114/400
# 808/808 - 0s - loss: 0.1808
# Epoch 115/400
# 808/808 - 0s - loss: 0.1811
# Epoch 116/400
# 808/808 - 0s - loss: 0.1877
# Epoch 117/400
# 808/808 - 0s - loss: 0.1770
# Epoch 118/400
# 808/808 - 0s - loss: 0.1825
# Epoch 119/400
# 808/808 - 0s - loss: 0.1788
# Epoch 120/400
# 808/808 - 0s - loss: 0.1782
# Epoch 121/400
# 808/808 - 0s - loss: 0.1841
# Epoch 122/400
# 808/808 - 0s - loss: 0.1789
# Epoch 123/400
# 808/808 - 0s - loss: 0.1788
# Epoch 124/400
# 808/808 - 0s - loss: 0.1879
# Epoch 125/400
# 808/808 - 0s - loss: 0.1843
# Epoch 126/400
# 808/808 - 0s - loss: 0.1740
# Epoch 127/400
# 808/808 - 0s - loss: 0.1766
# Epoch 128/400
# 808/808 - 0s - loss: 0.1753
# Epoch 129/400
# 808/808 - 0s - loss: 0.1764
# Epoch 130/400
# 808/808 - 0s - loss: 0.1748
# Epoch 131/400
# 808/808 - 0s - loss: 0.1728
# Epoch 132/400
# 808/808 - 0s - loss: 0.1787
# Epoch 133/400
# 808/808 - 0s - loss: 0.1712
# Epoch 134/400
# 808/808 - 0s - loss: 0.1786
# Epoch 135/400
# 808/808 - 0s - loss: 0.1796
# Epoch 136/400
# 808/808 - 0s - loss: 0.1834
# Epoch 137/400
# 808/808 - 0s - loss: 0.1670
# Epoch 138/400
# 808/808 - 0s - loss: 0.1710
# Epoch 139/400
# 808/808 - 0s - loss: 0.1758
# Epoch 140/400
# 808/808 - 0s - loss: 0.1716
# Epoch 141/400
# 808/808 - 0s - loss: 0.1698
# Epoch 142/400
# 808/808 - 0s - loss: 0.1775
# Epoch 143/400
# 808/808 - 0s - loss: 0.1699
# Epoch 144/400
# 808/808 - 0s - loss: 0.1724
# Epoch 145/400
# 808/808 - 0s - loss: 0.1740
# Epoch 146/400
# 808/808 - 0s - loss: 0.1677
# Epoch 147/400
# 808/808 - 0s - loss: 0.1719
# Epoch 148/400
# 808/808 - 0s - loss: 0.1823
# Epoch 149/400
# 808/808 - 0s - loss: 0.1693
# Epoch 150/400
# 808/808 - 0s - loss: 0.1762
# Epoch 151/400
# 808/808 - 0s - loss: 0.1659
# Epoch 152/400
# 808/808 - 0s - loss: 0.1681
# Epoch 153/400
# 808/808 - 0s - loss: 0.1714
# Epoch 154/400
# 808/808 - 0s - loss: 0.1692
# Epoch 155/400
# 808/808 - 0s - loss: 0.1753
# Epoch 156/400
# 808/808 - 0s - loss: 0.1679
# Epoch 157/400
# 808/808 - 0s - loss: 0.1727
# Epoch 158/400
# 808/808 - 0s - loss: 0.1741
# Epoch 159/400
# 808/808 - 0s - loss: 0.1717
# Epoch 160/400
# 808/808 - 0s - loss: 0.1744
# Epoch 161/400
# 808/808 - 0s - loss: 0.1642
# Epoch 162/400
# 808/808 - 0s - loss: 0.1684
# Epoch 163/400
# 808/808 - 0s - loss: 0.1728
# Epoch 164/400
# 808/808 - 0s - loss: 0.1695
# Epoch 165/400
# 808/808 - 0s - loss: 0.1654
# Epoch 166/400
# 808/808 - 0s - loss: 0.1648
# Epoch 167/400
# 808/808 - 0s - loss: 0.1738
# Epoch 168/400
# 808/808 - 0s - loss: 0.1708
# Epoch 169/400
# 808/808 - 0s - loss: 0.1802
# Epoch 170/400
# 808/808 - 0s - loss: 0.1697
# Epoch 171/400
# 808/808 - 0s - loss: 0.1627
# Epoch 172/400
# 808/808 - 0s - loss: 0.1682
# Epoch 173/400
# 808/808 - 0s - loss: 0.1680
# Epoch 174/400
# 808/808 - 0s - loss: 0.1763
# Epoch 175/400
# 808/808 - 0s - loss: 0.1686
# Epoch 176/400
# 808/808 - 0s - loss: 0.1722
# Epoch 177/400
# 808/808 - 0s - loss: 0.1693
# Epoch 178/400
# 808/808 - 0s - loss: 0.1703
# Epoch 179/400
# 808/808 - 0s - loss: 0.1669
# Epoch 180/400
# 808/808 - 0s - loss: 0.1625
# Epoch 181/400
# 808/808 - 0s - loss: 0.1676
# Epoch 182/400
# 808/808 - 0s - loss: 0.1592
# Epoch 183/400
# 808/808 - 0s - loss: 0.1667
# Epoch 184/400
# 808/808 - 0s - loss: 0.1648
# Epoch 185/400
# 808/808 - 0s - loss: 0.1698
# Epoch 186/400
# 808/808 - 0s - loss: 0.1662
# Epoch 187/400
# 808/808 - 0s - loss: 0.1642
# Epoch 188/400
# 808/808 - 0s - loss: 0.1658
# Epoch 189/400
# 808/808 - 0s - loss: 0.1681
# Epoch 190/400
# 808/808 - 0s - loss: 0.1553
# Epoch 191/400
# 808/808 - 0s - loss: 0.1601
# Epoch 192/400
# 808/808 - 0s - loss: 0.1711
# Epoch 193/400
# 808/808 - 0s - loss: 0.1602
# Epoch 194/400
# 808/808 - 0s - loss: 0.1664
# Epoch 195/400
# 808/808 - 0s - loss: 0.1683
# Epoch 196/400
# 808/808 - 0s - loss: 0.1579
# Epoch 197/400
# 808/808 - 0s - loss: 0.1632
# Epoch 198/400
# 808/808 - 0s - loss: 0.1580
# Epoch 199/400
# 808/808 - 0s - loss: 0.1666
# Epoch 200/400
# 808/808 - 0s - loss: 0.1702
# Epoch 201/400
# 808/808 - 0s - loss: 0.1650
# Epoch 202/400
# 808/808 - 0s - loss: 0.1655
# Epoch 203/400
# 808/808 - 0s - loss: 0.1664
# Epoch 204/400
# 808/808 - 0s - loss: 0.1643
# Epoch 205/400
# 808/808 - 0s - loss: 0.1568
# Epoch 206/400
# 808/808 - 0s - loss: 0.1677
# Epoch 207/400
# 808/808 - 0s - loss: 0.1584
# Epoch 208/400
# 808/808 - 0s - loss: 0.1626
# Epoch 209/400
# 808/808 - 0s - loss: 0.1620
# Epoch 210/400
# 808/808 - 0s - loss: 0.1632
# Epoch 211/400
# 808/808 - 0s - loss: 0.1596
# Epoch 212/400
# 808/808 - 0s - loss: 0.1613
# Epoch 213/400
# 808/808 - 0s - loss: 0.1730
# Epoch 214/400
# 808/808 - 0s - loss: 0.1579
# Epoch 215/400
# 808/808 - 0s - loss: 0.1573
# Epoch 216/400
# 808/808 - 0s - loss: 0.1619
# Epoch 217/400
# 808/808 - 0s - loss: 0.1725
# Epoch 218/400
# 808/808 - 0s - loss: 0.1617
# Epoch 219/400
# 808/808 - 0s - loss: 0.1639
# Epoch 220/400
# 808/808 - 0s - loss: 0.1589
# Epoch 221/400
# 808/808 - 0s - loss: 0.1648
# Epoch 222/400
# 808/808 - 0s - loss: 0.1506
# Epoch 223/400
# 808/808 - 0s - loss: 0.1597
# Epoch 224/400
# 808/808 - 0s - loss: 0.1623
# Epoch 225/400
# 808/808 - 0s - loss: 0.1554
# Epoch 226/400
# 808/808 - 0s - loss: 0.1530
# Epoch 227/400
# 808/808 - 0s - loss: 0.1573
# Epoch 228/400
# 808/808 - 0s - loss: 0.1501
# Epoch 229/400
# 808/808 - 0s - loss: 0.1504
# Epoch 230/400
# 808/808 - 0s - loss: 0.1555
# Epoch 231/400
# 808/808 - 0s - loss: 0.1539
# Epoch 232/400
# 808/808 - 0s - loss: 0.1622
# Epoch 233/400
# 808/808 - 0s - loss: 0.1531
# Epoch 234/400
# 808/808 - 0s - loss: 0.1623
# Epoch 235/400
# 808/808 - 0s - loss: 0.1603
# Epoch 236/400
# 808/808 - 0s - loss: 0.1585
# Epoch 237/400
# 808/808 - 0s - loss: 0.1556
# Epoch 238/400
# 808/808 - 0s - loss: 0.1639
# Epoch 239/400
# 808/808 - 0s - loss: 0.1559
# Epoch 240/400
# 808/808 - 0s - loss: 0.1544
# Epoch 241/400
# 808/808 - 0s - loss: 0.1584
# Epoch 242/400
# 808/808 - 0s - loss: 0.1608
# Epoch 243/400
# 808/808 - 0s - loss: 0.1553
# Epoch 244/400
# 808/808 - 0s - loss: 0.1560
# Epoch 245/400
# 808/808 - 0s - loss: 0.1534
# Epoch 246/400
# 808/808 - 0s - loss: 0.1550
# Epoch 247/400
# 808/808 - 0s - loss: 0.1478
# Epoch 248/400
# 808/808 - 0s - loss: 0.1578
# Epoch 249/400
# 808/808 - 0s - loss: 0.1631
# Epoch 250/400
# 808/808 - 0s - loss: 0.1573
# Epoch 251/400
# 808/808 - 0s - loss: 0.1605
# Epoch 252/400
# 808/808 - 0s - loss: 0.1565
# Epoch 253/400
# 808/808 - 0s - loss: 0.1539
# Epoch 254/400
# 808/808 - 0s - loss: 0.1704
# Epoch 255/400
# 808/808 - 0s - loss: 0.1553
# Epoch 256/400
# 808/808 - 0s - loss: 0.1540
# Epoch 257/400
# 808/808 - 0s - loss: 0.1585
# Epoch 258/400
# 808/808 - 0s - loss: 0.1528
# Epoch 259/400
# 808/808 - 0s - loss: 0.1620
# Epoch 260/400
# 808/808 - 0s - loss: 0.1678
# Epoch 261/400
# 808/808 - 0s - loss: 0.1532
# Epoch 262/400
# 808/808 - 0s - loss: 0.1479
# Epoch 263/400
# 808/808 - 0s - loss: 0.1503
# Epoch 264/400
# 808/808 - 0s - loss: 0.1488
# Epoch 265/400
# 808/808 - 0s - loss: 0.1497
# Epoch 266/400
# 808/808 - 0s - loss: 0.1522
# Epoch 267/400
# 808/808 - 0s - loss: 0.1574
# Epoch 268/400
# 808/808 - 0s - loss: 0.1459
# Epoch 269/400
# 808/808 - 0s - loss: 0.1485
# Epoch 270/400
# 808/808 - 0s - loss: 0.1498
# Epoch 271/400
# 808/808 - 0s - loss: 0.1495
# Epoch 272/400
# 808/808 - 0s - loss: 0.1545
# Epoch 273/400
# 808/808 - 0s - loss: 0.1490
# Epoch 274/400
# 808/808 - 0s - loss: 0.1524
# Epoch 275/400
# 808/808 - 0s - loss: 0.1455
# Epoch 276/400
# 808/808 - 0s - loss: 0.1503
# Epoch 277/400
# 808/808 - 0s - loss: 0.1485
# Epoch 278/400
# 808/808 - 0s - loss: 0.1494
# Epoch 279/400
# 808/808 - 0s - loss: 0.1539
# Epoch 280/400
# 808/808 - 0s - loss: 0.1524
# Epoch 281/400
# 808/808 - 0s - loss: 0.1535
# Epoch 282/400
# 808/808 - 0s - loss: 0.1632
# Epoch 283/400
# 808/808 - 0s - loss: 0.1480
# Epoch 284/400
# 808/808 - 0s - loss: 0.1529
# Epoch 285/400
# 808/808 - 0s - loss: 0.1408
# Epoch 286/400
# 808/808 - 0s - loss: 0.1529
# Epoch 287/400
# 808/808 - 0s - loss: 0.1490
# Epoch 288/400
# 808/808 - 0s - loss: 0.1474
# Epoch 289/400
# 808/808 - 0s - loss: 0.1520
# Epoch 290/400
# 808/808 - 0s - loss: 0.1464
# Epoch 291/400
# 808/808 - 0s - loss: 0.1540
# Epoch 292/400
# 808/808 - 0s - loss: 0.1510
# Epoch 293/400
# 808/808 - 0s - loss: 0.1440
# Epoch 294/400
# 808/808 - 0s - loss: 0.1483
# Epoch 295/400
# 808/808 - 0s - loss: 0.1448
# Epoch 296/400
# 808/808 - 0s - loss: 0.1446
# Epoch 297/400
# 808/808 - 0s - loss: 0.1486
# Epoch 298/400
# 808/808 - 0s - loss: 0.1492
# Epoch 299/400
# 808/808 - 0s - loss: 0.1418
# Epoch 300/400
# 808/808 - 0s - loss: 0.1490
# Epoch 301/400
# 808/808 - 0s - loss: 0.1477
# Epoch 302/400
# 808/808 - 0s - loss: 0.1496
# Epoch 303/400
# 808/808 - 0s - loss: 0.1467
# Epoch 304/400
# 808/808 - 0s - loss: 0.1437
# Epoch 305/400
# 808/808 - 0s - loss: 0.1489
# Epoch 306/400
# 808/808 - 0s - loss: 0.1484
# Epoch 307/400
# 808/808 - 0s - loss: 0.1389
# Epoch 308/400
# 808/808 - 0s - loss: 0.1538
# Epoch 309/400
# 808/808 - 0s - loss: 0.1425
# Epoch 310/400
# 808/808 - 0s - loss: 0.1541
# Epoch 311/400
# 808/808 - 0s - loss: 0.1477
# Epoch 312/400
# 808/808 - 0s - loss: 0.1460
# Epoch 313/400
# 808/808 - 0s - loss: 0.1452
# Epoch 314/400
# 808/808 - 0s - loss: 0.1392
# Epoch 315/400
# 808/808 - 0s - loss: 0.1414
# Epoch 316/400
# 808/808 - 0s - loss: 0.1421
# Epoch 317/400
# 808/808 - 0s - loss: 0.1548
# Epoch 318/400
# 808/808 - 0s - loss: 0.1541
# Epoch 319/400
# 808/808 - 0s - loss: 0.1497
# Epoch 320/400
# 808/808 - 0s - loss: 0.1435
# Epoch 321/400
# 808/808 - 0s - loss: 0.1421
# Epoch 322/400
# 808/808 - 0s - loss: 0.1464
# Epoch 323/400
# 808/808 - 0s - loss: 0.1500
# Epoch 324/400
# 808/808 - 0s - loss: 0.1396
# Epoch 325/400
# 808/808 - 0s - loss: 0.1468
# Epoch 326/400
# 808/808 - 0s - loss: 0.1447
# Epoch 327/400
# 808/808 - 0s - loss: 0.1502
# Epoch 328/400
# 808/808 - 0s - loss: 0.1446
# Epoch 329/400
# 808/808 - 0s - loss: 0.1446
# Epoch 330/400
# 808/808 - 0s - loss: 0.1442
# Epoch 331/400
# 808/808 - 0s - loss: 0.1445
# Epoch 332/400
# 808/808 - 0s - loss: 0.1546
# Epoch 333/400
# 808/808 - 0s - loss: 0.1462
# Epoch 334/400
# 808/808 - 0s - loss: 0.1482
# Epoch 335/400
# 808/808 - 0s - loss: 0.1372
# Epoch 336/400
# 808/808 - 0s - loss: 0.1403
# Epoch 337/400
# 808/808 - 0s - loss: 0.1416
# Epoch 338/400
# 808/808 - 0s - loss: 0.1450
# Epoch 339/400
# 808/808 - 0s - loss: 0.1469
# Epoch 340/400
# 808/808 - 0s - loss: 0.1400
# Epoch 341/400
# 808/808 - 0s - loss: 0.1506
# Epoch 342/400
# 808/808 - 0s - loss: 0.1458
# Epoch 343/400
# 808/808 - 0s - loss: 0.1443
# Epoch 344/400
# 808/808 - 0s - loss: 0.1412
# Epoch 345/400
# 808/808 - 0s - loss: 0.1446
# Epoch 346/400
# 808/808 - 0s - loss: 0.1396
# Epoch 347/400
# 808/808 - 0s - loss: 0.1499
# Epoch 348/400
# 808/808 - 0s - loss: 0.1423
# Epoch 349/400
# 808/808 - 0s - loss: 0.1449
# Epoch 350/400
# 808/808 - 0s - loss: 0.1441
# Epoch 351/400
# 808/808 - 0s - loss: 0.1474
# Epoch 352/400
# 808/808 - 0s - loss: 0.1484
# Epoch 353/400
# 808/808 - 0s - loss: 0.1462
# Epoch 354/400
# 808/808 - 0s - loss: 0.1478
# Epoch 355/400
# 808/808 - 0s - loss: 0.1441
# Epoch 356/400
# 808/808 - 0s - loss: 0.1419
# Epoch 357/400
# 808/808 - 0s - loss: 0.1467
# Epoch 358/400
# 808/808 - 0s - loss: 0.1359
# Epoch 359/400
# 808/808 - 0s - loss: 0.1428
# Epoch 360/400
# 808/808 - 0s - loss: 0.1451
# Epoch 361/400
# 808/808 - 0s - loss: 0.1341
# Epoch 362/400
# 808/808 - 0s - loss: 0.1385
# Epoch 363/400
# 808/808 - 0s - loss: 0.1426
# Epoch 364/400
# 808/808 - 0s - loss: 0.1452
# Epoch 365/400
# 808/808 - 0s - loss: 0.1537
# Epoch 366/400
# 808/808 - 0s - loss: 0.1397
# Epoch 367/400
# 808/808 - 0s - loss: 0.1437
# Epoch 368/400
# 808/808 - 0s - loss: 0.1391
# Epoch 369/400
# 808/808 - 0s - loss: 0.1445
# Epoch 370/400
# 808/808 - 0s - loss: 0.1436
# Epoch 371/400
# 808/808 - 0s - loss: 0.1396
# Epoch 372/400
# 808/808 - 0s - loss: 0.1381
# Epoch 373/400
# 808/808 - 0s - loss: 0.1452
# Epoch 374/400
# 808/808 - 0s - loss: 0.1490
# Epoch 375/400
# 808/808 - 0s - loss: 0.1416
# Epoch 376/400
# 808/808 - 0s - loss: 0.1391
# Epoch 377/400
# 808/808 - 0s - loss: 0.1447
# Epoch 378/400
# 808/808 - 0s - loss: 0.1403
# Epoch 379/400
# 808/808 - 0s - loss: 0.1406
# Epoch 380/400
# 808/808 - 0s - loss: 0.1359
# Epoch 381/400
# 808/808 - 0s - loss: 0.1392
# Epoch 382/400
# 808/808 - 0s - loss: 0.1403
# Epoch 383/400
# 808/808 - 0s - loss: 0.1423
# Epoch 384/400
# 808/808 - 0s - loss: 0.1412
# Epoch 385/400
# 808/808 - 0s - loss: 0.1412
# Epoch 386/400
# 808/808 - 0s - loss: 0.1374
# Epoch 387/400
# 808/808 - 0s - loss: 0.1535
# Epoch 388/400
# 808/808 - 0s - loss: 0.1340
# Epoch 389/400
# 808/808 - 0s - loss: 0.1338
# Epoch 390/400
# 808/808 - 0s - loss: 0.1465
# Epoch 391/400
# 808/808 - 0s - loss: 0.1331
# Epoch 392/400
# 808/808 - 0s - loss: 0.1410
# Epoch 393/400
# 808/808 - 0s - loss: 0.1373
# Epoch 394/400
# 808/808 - 0s - loss: 0.1483
# Epoch 395/400
# 808/808 - 0s - loss: 0.1436
# Epoch 396/400
# 808/808 - 0s - loss: 0.1392
# Epoch 397/400
# 808/808 - 0s - loss: 0.1358
# Epoch 398/400
# 808/808 - 0s - loss: 0.1486
# Epoch 399/400
# 808/808 - 0s - loss: 0.1442
# Epoch 400/400
# 808/808 - 0s - loss: 0.1348

# %%
#Extracting the compressed representation of the indicators
encoder = Model(inputs=visible, outputs=bottleneck)
bottleneck_rep = encoder.predict(X)

# %%
#Creating a new array using the bottleneck representation to serve as environment signals
b = pd.DataFrame(bottleneck_rep)
d = PFE_data.copy().iloc[199:]
d = d[['Low','Volume']]
d['AE Col 1'] = b[0].values
d['AE Col 2'] = b[1].values
d['AE Col 3'] = b[2].values
env_sig = StandardScaler().fit_transform(d)
env_df = pd.DataFrame(env_sig)
env_df.columns = ['Low','Volume','AE Col 1','AE Col 2','AE Col 3']

# %%
#Creating the AE_powered reinforcement bot
wind_size = 20

#Defining a function that will yield the signals of the environment
def env_signals(env):
    start_index = env.frame_bound[0]-env.window_size
    end_index = env.frame_bound[1]
    prices = env.df.iloc[start_index:end_index]['Low'].to_numpy()
    signal_features = env.df.iloc[start_index:end_index].to_numpy()
    return prices, signal_features

#Creating an environment class
class environment(StocksEnv):
    _process_data = env_signals

#Building the environment
env = environment(df=env_df,window_size=wind_size,frame_bound=(wind_size,100))
make_env = lambda: env
env = DummyVecEnv([make_env])

#Training the model
model_20 = A2C('MlpLstmPolicy', env, verbose=1) 
model_20.learn(total_timesteps=40000)
# Out:
# ---------------------------------
# | explained_variance | -95.8    |
# | fps                | 10       |
# | nupdates           | 1        |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 5        |
# | value_loss         | 0.00661  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.47    |
# | fps                | 166      |
# | nupdates           | 100      |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 500      |
# | value_loss         | 0.046    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -122     |
# | fps                | 176      |
# | nupdates           | 200      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 1000     |
# | value_loss         | 0.0236   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.503    |
# | fps                | 184      |
# | nupdates           | 300      |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 1500     |
# | value_loss         | 0.0799   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.346   |
# | fps                | 188      |
# | nupdates           | 400      |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 2000     |
# | value_loss         | 0.00632  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0862   |
# | fps                | 190      |
# | nupdates           | 500      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 2500     |
# | value_loss         | 0.116    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.328    |
# | fps                | 191      |
# | nupdates           | 600      |
# | policy_entropy     | 0.69     |
# | total_timesteps    | 3000     |
# | value_loss         | 0.007    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.156    |
# | fps                | 192      |
# | nupdates           | 700      |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 3500     |
# | value_loss         | 0.00113  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.04    |
# | fps                | 193      |
# | nupdates           | 800      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 4000     |
# | value_loss         | 0.00397  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.167    |
# | fps                | 194      |
# | nupdates           | 900      |
# | policy_entropy     | 0.687    |
# | total_timesteps    | 4500     |
# | value_loss         | 0.031    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -149     |
# | fps                | 194      |
# | nupdates           | 1000     |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 5000     |
# | value_loss         | 0.00614  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -14.3    |
# | fps                | 195      |
# | nupdates           | 1100     |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 5500     |
# | value_loss         | 0.0133   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.116    |
# | fps                | 195      |
# | nupdates           | 1200     |
# | policy_entropy     | 0.682    |
# | total_timesteps    | 6000     |
# | value_loss         | 0.00604  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.307    |
# | fps                | 195      |
# | nupdates           | 1300     |
# | policy_entropy     | 0.678    |
# | total_timesteps    | 6500     |
# | value_loss         | 0.0126   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.57    |
# | fps                | 195      |
# | nupdates           | 1400     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 7000     |
# | value_loss         | 0.00687  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.406   |
# | fps                | 195      |
# | nupdates           | 1500     |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 7500     |
# | value_loss         | 0.0853   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -27.4    |
# | fps                | 195      |
# | nupdates           | 1600     |
# | policy_entropy     | 0.667    |
# | total_timesteps    | 8000     |
# | value_loss         | 0.0186   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.07    |
# | fps                | 195      |
# | nupdates           | 1700     |
# | policy_entropy     | 0.677    |
# | total_timesteps    | 8500     |
# | value_loss         | 0.00874  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.559    |
# | fps                | 195      |
# | nupdates           | 1800     |
# | policy_entropy     | 0.676    |
# | total_timesteps    | 9000     |
# | value_loss         | 0.0057   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.281   |
# | fps                | 195      |
# | nupdates           | 1900     |
# | policy_entropy     | 0.674    |
# | total_timesteps    | 9500     |
# | value_loss         | 0.0177   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.07    |
# | fps                | 195      |
# | nupdates           | 2000     |
# | policy_entropy     | 0.69     |
# | total_timesteps    | 10000    |
# | value_loss         | 0.0132   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -17.2    |
# | fps                | 195      |
# | nupdates           | 2100     |
# | policy_entropy     | 0.684    |
# | total_timesteps    | 10500    |
# | value_loss         | 0.00487  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -23.9    |
# | fps                | 195      |
# | nupdates           | 2200     |
# | policy_entropy     | 0.567    |
# | total_timesteps    | 11000    |
# | value_loss         | 0.00305  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.713    |
# | fps                | 196      |
# | nupdates           | 2300     |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 11500    |
# | value_loss         | 0.000784 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -8.15    |
# | fps                | 195      |
# | nupdates           | 2400     |
# | policy_entropy     | 0.487    |
# | total_timesteps    | 12000    |
# | value_loss         | 0.0267   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -417     |
# | fps                | 195      |
# | nupdates           | 2500     |
# | policy_entropy     | 0.482    |
# | total_timesteps    | 12500    |
# | value_loss         | 0.00507  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -8.22    |
# | fps                | 195      |
# | nupdates           | 2600     |
# | policy_entropy     | 0.506    |
# | total_timesteps    | 13000    |
# | value_loss         | 0.00149  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -6.05    |
# | fps                | 195      |
# | nupdates           | 2700     |
# | policy_entropy     | 0.397    |
# | total_timesteps    | 13500    |
# | value_loss         | 0.526    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -6.56    |
# | fps                | 195      |
# | nupdates           | 2800     |
# | policy_entropy     | 0.532    |
# | total_timesteps    | 14000    |
# | value_loss         | 0.00335  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -18.6    |
# | fps                | 196      |
# | nupdates           | 2900     |
# | policy_entropy     | 0.511    |
# | total_timesteps    | 14500    |
# | value_loss         | 0.00467  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -468     |
# | fps                | 196      |
# | nupdates           | 3000     |
# | policy_entropy     | 0.113    |
# | total_timesteps    | 15000    |
# | value_loss         | 0.00495  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.76    |
# | fps                | 196      |
# | nupdates           | 3100     |
# | policy_entropy     | 0.519    |
# | total_timesteps    | 15500    |
# | value_loss         | 0.00143  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.869   |
# | fps                | 196      |
# | nupdates           | 3200     |
# | policy_entropy     | 0.564    |
# | total_timesteps    | 16000    |
# | value_loss         | 0.0126   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -33.1    |
# | fps                | 196      |
# | nupdates           | 3300     |
# | policy_entropy     | 0.0733   |
# | total_timesteps    | 16500    |
# | value_loss         | 0.00134  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.41    |
# | fps                | 196      |
# | nupdates           | 3400     |
# | policy_entropy     | 0.583    |
# | total_timesteps    | 17000    |
# | value_loss         | 0.00408  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.7     |
# | fps                | 197      |
# | nupdates           | 3500     |
# | policy_entropy     | 0.515    |
# | total_timesteps    | 17500    |
# | value_loss         | 0.00058  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -16.5    |
# | fps                | 197      |
# | nupdates           | 3600     |
# | policy_entropy     | 0.0174   |
# | total_timesteps    | 18000    |
# | value_loss         | 0.00132  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -21      |
# | fps                | 197      |
# | nupdates           | 3700     |
# | policy_entropy     | 0.395    |
# | total_timesteps    | 18500    |
# | value_loss         | 0.0397   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.563   |
# | fps                | 197      |
# | nupdates           | 3800     |
# | policy_entropy     | 0.601    |
# | total_timesteps    | 19000    |
# | value_loss         | 0.000134 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -26      |
# | fps                | 197      |
# | nupdates           | 3900     |
# | policy_entropy     | 0.0322   |
# | total_timesteps    | 19500    |
# | value_loss         | 0.00184  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -7.98    |
# | fps                | 197      |
# | nupdates           | 4000     |
# | policy_entropy     | 0.458    |
# | total_timesteps    | 20000    |
# | value_loss         | 0.0108   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.1     |
# | fps                | 197      |
# | nupdates           | 4100     |
# | policy_entropy     | 0.403    |
# | total_timesteps    | 20500    |
# | value_loss         | 0.000972 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -6.12    |
# | fps                | 197      |
# | nupdates           | 4200     |
# | policy_entropy     | 0.0185   |
# | total_timesteps    | 21000    |
# | value_loss         | 0.00121  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -4.92    |
# | fps                | 197      |
# | nupdates           | 4300     |
# | policy_entropy     | 0.475    |
# | total_timesteps    | 21500    |
# | value_loss         | 0.00747  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.608    |
# | fps                | 197      |
# | nupdates           | 4400     |
# | policy_entropy     | 0.432    |
# | total_timesteps    | 22000    |
# | value_loss         | 0.0013   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -9.6     |
# | fps                | 197      |
# | nupdates           | 4500     |
# | policy_entropy     | 0.00399  |
# | total_timesteps    | 22500    |
# | value_loss         | 0.0006   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -5.15    |
# | fps                | 197      |
# | nupdates           | 4600     |
# | policy_entropy     | 0.484    |
# | total_timesteps    | 23000    |
# | value_loss         | 0.00786  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.142    |
# | fps                | 197      |
# | nupdates           | 4700     |
# | policy_entropy     | 0.393    |
# | total_timesteps    | 23500    |
# | value_loss         | 0.00256  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -83.9    |
# | fps                | 197      |
# | nupdates           | 4800     |
# | policy_entropy     | 0.00534  |
# | total_timesteps    | 24000    |
# | value_loss         | 0.000523 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -13.7    |
# | fps                | 197      |
# | nupdates           | 4900     |
# | policy_entropy     | 0.624    |
# | total_timesteps    | 24500    |
# | value_loss         | 0.000437 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -8.64    |
# | fps                | 197      |
# | nupdates           | 5000     |
# | policy_entropy     | 0.651    |
# | total_timesteps    | 25000    |
# | value_loss         | 0.00171  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -37      |
# | fps                | 197      |
# | nupdates           | 5100     |
# | policy_entropy     | 0.0059   |
# | total_timesteps    | 25500    |
# | value_loss         | 0.00113  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -3.07    |
# | fps                | 197      |
# | nupdates           | 5200     |
# | policy_entropy     | 0.265    |
# | total_timesteps    | 26000    |
# | value_loss         | 0.000894 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.212    |
# | fps                | 197      |
# | nupdates           | 5300     |
# | policy_entropy     | 0.499    |
# | total_timesteps    | 26500    |
# | value_loss         | 0.00341  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -39.3    |
# | fps                | 197      |
# | nupdates           | 5400     |
# | policy_entropy     | 0.0139   |
# | total_timesteps    | 27000    |
# | value_loss         | 0.00087  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.439   |
# | fps                | 197      |
# | nupdates           | 5500     |
# | policy_entropy     | 0.351    |
# | total_timesteps    | 27500    |
# | value_loss         | 0.000419 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -3.53    |
# | fps                | 197      |
# | nupdates           | 5600     |
# | policy_entropy     | 0.48     |
# | total_timesteps    | 28000    |
# | value_loss         | 0.000806 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -22.9    |
# | fps                | 197      |
# | nupdates           | 5700     |
# | policy_entropy     | 0.00913  |
# | total_timesteps    | 28500    |
# | value_loss         | 0.00203  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -4.84    |
# | fps                | 197      |
# | nupdates           | 5800     |
# | policy_entropy     | 0.389    |
# | total_timesteps    | 29000    |
# | value_loss         | 0.00192  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.78    |
# | fps                | 197      |
# | nupdates           | 5900     |
# | policy_entropy     | 0.226    |
# | total_timesteps    | 29500    |
# | value_loss         | 0.000435 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.501   |
# | fps                | 197      |
# | nupdates           | 6000     |
# | policy_entropy     | 0.00519  |
# | total_timesteps    | 30000    |
# | value_loss         | 0.000866 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.98    |
# | fps                | 197      |
# | nupdates           | 6100     |
# | policy_entropy     | 0.578    |
# | total_timesteps    | 30500    |
# | value_loss         | 0.00428  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.21    |
# | fps                | 197      |
# | nupdates           | 6200     |
# | policy_entropy     | 0.41     |
# | total_timesteps    | 31000    |
# | value_loss         | 0.00036  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.38    |
# | fps                | 197      |
# | nupdates           | 6300     |
# | policy_entropy     | 0.00868  |
# | total_timesteps    | 31500    |
# | value_loss         | 0.000435 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -27      |
# | fps                | 197      |
# | nupdates           | 6400     |
# | policy_entropy     | 0.449    |
# | total_timesteps    | 32000    |
# | value_loss         | 0.00619  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.47    |
# | fps                | 197      |
# | nupdates           | 6500     |
# | policy_entropy     | 0.216    |
# | total_timesteps    | 32500    |
# | value_loss         | 0.00233  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -69.6    |
# | fps                | 197      |
# | nupdates           | 6600     |
# | policy_entropy     | 0.127    |
# | total_timesteps    | 33000    |
# | value_loss         | 0.00225  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.94     |
# | fps                | 197      |
# | nupdates           | 6700     |
# | policy_entropy     | 0.45     |
# | total_timesteps    | 33500    |
# | value_loss         | 0.0122   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.18    |
# | fps                | 197      |
# | nupdates           | 6800     |
# | policy_entropy     | 0.0323   |
# | total_timesteps    | 34000    |
# | value_loss         | 0.000365 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -10.6    |
# | fps                | 197      |
# | nupdates           | 6900     |
# | policy_entropy     | 0.151    |
# | total_timesteps    | 34500    |
# | value_loss         | 0.000225 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.972    |
# | fps                | 197      |
# | nupdates           | 7000     |
# | policy_entropy     | 0.478    |
# | total_timesteps    | 35000    |
# | value_loss         | 0.00641  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.552   |
# | fps                | 197      |
# | nupdates           | 7100     |
# | policy_entropy     | 0.302    |
# | total_timesteps    | 35500    |
# | value_loss         | 0.0038   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -42.3    |
# | fps                | 197      |
# | nupdates           | 7200     |
# | policy_entropy     | 0.155    |
# | total_timesteps    | 36000    |
# | value_loss         | 0.000986 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.97     |
# | fps                | 197      |
# | nupdates           | 7300     |
# | policy_entropy     | 0.285    |
# | total_timesteps    | 36500    |
# | value_loss         | 0.00528  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.892    |
# | fps                | 197      |
# | nupdates           | 7400     |
# | policy_entropy     | 0.254    |
# | total_timesteps    | 37000    |
# | value_loss         | 0.000346 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.95     |
# | fps                | 197      |
# | nupdates           | 7500     |
# | policy_entropy     | 0.215    |
# | total_timesteps    | 37500    |
# | value_loss         | 0.00358  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.98     |
# | fps                | 197      |
# | nupdates           | 7600     |
# | policy_entropy     | 0.4      |
# | total_timesteps    | 38000    |
# | value_loss         | 0.00676  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.111   |
# | fps                | 197      |
# | nupdates           | 7700     |
# | policy_entropy     | 0.335    |
# | total_timesteps    | 38500    |
# | value_loss         | 0.0027   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.975    |
# | fps                | 197      |
# | nupdates           | 7800     |
# | policy_entropy     | 0.218    |
# | total_timesteps    | 39000    |
# | value_loss         | 0.00235  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.502    |
# | fps                | 197      |
# | nupdates           | 7900     |
# | policy_entropy     | 0.367    |
# | total_timesteps    | 39500    |
# | value_loss         | 0.115    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.372    |
# | fps                | 197      |
# | nupdates           | 8000     |
# | policy_entropy     | 0.496    |
# | total_timesteps    | 40000    |
# | value_loss         | 0.00573  |
# ---------------------------------

# %%
#Testing the AE_powered RL model and viewing its profit
env = environment(df=env_df, window_size=wind_size, frame_bound=(100,150))
env.seed(2021)
obs = env.reset()
while True: 
    obs = obs[np.newaxis, ...]
    action, _states = model_20.predict(obs)
    obs, rewards, done, info = env.step(action)
    if done:
        print("The total profit after 50 days is ",info['total_profit'])
        break
# Out:
# The total profit after 50 days is  2.018200548603831

# %%
#Creating a dataframe for the baseline model
merged = pd.merge(PFE_data.iloc[199:],ind,on='Date',how='left')
columns = list(merged.columns[6:])
columns.insert(0,'Low')
columns.insert(1,'Volume')
merged = merged[columns]
merged = merged.fillna(0)
merged_norm = StandardScaler().fit_transform(merged)
baseline_env_df = pd.DataFrame(merged_norm)
baseline_env_df.columns = merged.columns
baseline_env_df.index = merged.index
baseline_env_df
# Out:
#                  Low    Volume    SMA_10    SMA_50   SMA_200       RSI  \
# Date
# 2017-10-17 -0.724786 -0.799317 -0.711039 -1.251479 -1.664942  0.804564
# 2017-10-18 -0.712523 -0.770788 -0.715115 -1.233854 -1.659566  0.099926
# 2017-10-19 -0.697192 -0.386057 -0.707590 -1.214570 -1.653963  0.647575
# 2017-10-20 -0.638937 -0.549879 -0.695989 -1.193834 -1.648626  0.856601
# 2017-10-23 -0.556151 -0.717685 -0.687836 -1.172062 -1.643080  0.818092
# ...              ...       ...       ...       ...       ...       ...
# 2020-12-24  0.329252 -0.798410  0.547783  0.248972 -0.487492 -0.629651
# 2020-12-28  0.167669  0.030901  0.405673  0.264581 -0.475909 -0.830183
# 2020-12-29  0.203217 -0.230160  0.334288  0.272189 -0.459060 -0.691443
# 2020-12-30  0.174132 -0.112072  0.269182  0.278575 -0.446593 -0.838422
# 2020-12-31  0.041634  0.289325  0.235142  0.287614 -0.434365 -0.791772
#
#                 MACD       OBV        BB   Stoch_K   Stoch_D
# Date
# 2017-10-17  0.632641 -1.213382 -0.960629  0.542766  0.525008
# 2017-10-18  0.544598 -1.279149 -0.957472 -0.610238 -0.022266
# 2017-10-19  0.523659 -1.188881 -0.947571  0.420904  0.124050
# 2017-10-20  0.524656 -1.109045 -0.922519  0.818839  0.223071
# 2017-10-23  0.515976 -1.178194 -0.941767  0.263194  0.536350
# ...              ...       ...       ...       ...       ...
# 2020-12-24 -0.046667 -1.106263  1.500409 -1.602254 -1.797232
# 2020-12-28 -0.238963 -1.223085  1.544971 -1.847759 -1.781578
# 2020-12-29 -0.355151 -1.122888  1.638685 -1.722279 -1.857894
# 2020-12-30 -0.486795 -1.230606  1.772777 -1.879715 -1.957412
# 2020-12-31 -0.575279 -1.097325  1.812389 -1.649732 -1.886385
#
# [808 rows x 11 columns]

# %%
#Creating the baseline-model trading bot

#Defining a function that will yield the signals of the environment
def env_signals(env):
    start_index = env.frame_bound[0]-env.window_size
    end_index = env.frame_bound[1]
    prices = env.df.iloc[start_index:end_index]['Low'].to_numpy()
    signal_features = env.df.iloc[start_index:end_index].to_numpy()
    return prices, signal_features

#Creating an environment class
class environment(StocksEnv):
    _process_data = env_signals

#Building the environment
env = environment(df=baseline_env_df,window_size=wind_size,frame_bound=(wind_size,100))
make_env = lambda: env
env = DummyVecEnv([make_env])

#Training the model
model_20 = A2C('MlpLstmPolicy', env, verbose=1) 
model_20.learn(total_timesteps=40000)
# Out:
# ---------------------------------
# | explained_variance | -1.46    |
# | fps                | 10       |
# | nupdates           | 1        |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 5        |
# | value_loss         | 0.000513 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.64    |
# | fps                | 174      |
# | nupdates           | 100      |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 500      |
# | value_loss         | 0.00618  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -9.03    |
# | fps                | 188      |
# | nupdates           | 200      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 1000     |
# | value_loss         | 0.000757 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.623   |
# | fps                | 192      |
# | nupdates           | 300      |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 1500     |
# | value_loss         | 0.0182   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.407    |
# | fps                | 194      |
# | nupdates           | 400      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 2000     |
# | value_loss         | 0.000933 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -24.3    |
# | fps                | 197      |
# | nupdates           | 500      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 2500     |
# | value_loss         | 9.51e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0756   |
# | fps                | 198      |
# | nupdates           | 600      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 3000     |
# | value_loss         | 0.0141   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.387    |
# | fps                | 199      |
# | nupdates           | 700      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 3500     |
# | value_loss         | 0.000799 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.98    |
# | fps                | 200      |
# | nupdates           | 800      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 4000     |
# | value_loss         | 0.45     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.599   |
# | fps                | 200      |
# | nupdates           | 900      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 4500     |
# | value_loss         | 0.0171   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.363    |
# | fps                | 201      |
# | nupdates           | 1000     |
# | policy_entropy     | 0.68     |
# | total_timesteps    | 5000     |
# | value_loss         | 0.00148  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.37    |
# | fps                | 201      |
# | nupdates           | 1100     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 5500     |
# | value_loss         | 0.00517  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -36.3    |
# | fps                | 201      |
# | nupdates           | 1200     |
# | policy_entropy     | 0.683    |
# | total_timesteps    | 6000     |
# | value_loss         | 0.000357 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.18     |
# | fps                | 201      |
# | nupdates           | 1300     |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 6500     |
# | value_loss         | 0.011    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.482   |
# | fps                | 201      |
# | nupdates           | 1400     |
# | policy_entropy     | 0.673    |
# | total_timesteps    | 7000     |
# | value_loss         | 0.00517  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.735    |
# | fps                | 201      |
# | nupdates           | 1500     |
# | policy_entropy     | 0.669    |
# | total_timesteps    | 7500     |
# | value_loss         | 0.00189  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -312     |
# | fps                | 201      |
# | nupdates           | 1600     |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 8000     |
# | value_loss         | 0.0137   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.294   |
# | fps                | 201      |
# | nupdates           | 1700     |
# | policy_entropy     | 0.542    |
# | total_timesteps    | 8500     |
# | value_loss         | 0.0018   |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.27e+05 |
# | fps                | 201       |
# | nupdates           | 1800      |
# | policy_entropy     | 0.512     |
# | total_timesteps    | 9000      |
# | value_loss         | 0.0204    |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.26     |
# | fps                | 202      |
# | nupdates           | 1900     |
# | policy_entropy     | 0.667    |
# | total_timesteps    | 9500     |
# | value_loss         | 0.00681  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.25    |
# | fps                | 201      |
# | nupdates           | 2000     |
# | policy_entropy     | 0.651    |
# | total_timesteps    | 10000    |
# | value_loss         | 0.00746  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.183    |
# | fps                | 201      |
# | nupdates           | 2100     |
# | policy_entropy     | 0.666    |
# | total_timesteps    | 10500    |
# | value_loss         | 0.00609  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -19.2    |
# | fps                | 201      |
# | nupdates           | 2200     |
# | policy_entropy     | 0.662    |
# | total_timesteps    | 11000    |
# | value_loss         | 0.0437   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -13.3    |
# | fps                | 201      |
# | nupdates           | 2300     |
# | policy_entropy     | 0.662    |
# | total_timesteps    | 11500    |
# | value_loss         | 0.00168  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.612    |
# | fps                | 201      |
# | nupdates           | 2400     |
# | policy_entropy     | 0.58     |
# | total_timesteps    | 12000    |
# | value_loss         | 0.00775  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.885    |
# | fps                | 201      |
# | nupdates           | 2500     |
# | policy_entropy     | 0.653    |
# | total_timesteps    | 12500    |
# | value_loss         | 0.00131  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -98.3    |
# | fps                | 201      |
# | nupdates           | 2600     |
# | policy_entropy     | 0.463    |
# | total_timesteps    | 13000    |
# | value_loss         | 0.00215  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -33.1    |
# | fps                | 201      |
# | nupdates           | 2700     |
# | policy_entropy     | 0.411    |
# | total_timesteps    | 13500    |
# | value_loss         | 0.000564 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -94.3    |
# | fps                | 201      |
# | nupdates           | 2800     |
# | policy_entropy     | 0.612    |
# | total_timesteps    | 14000    |
# | value_loss         | 0.00133  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -6.06    |
# | fps                | 201      |
# | nupdates           | 2900     |
# | policy_entropy     | 0.675    |
# | total_timesteps    | 14500    |
# | value_loss         | 0.00108  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -131     |
# | fps                | 201      |
# | nupdates           | 3000     |
# | policy_entropy     | 0.659    |
# | total_timesteps    | 15000    |
# | value_loss         | 0.0184   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -4.61    |
# | fps                | 201      |
# | nupdates           | 3100     |
# | policy_entropy     | 0.659    |
# | total_timesteps    | 15500    |
# | value_loss         | 0.00445  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.175    |
# | fps                | 201      |
# | nupdates           | 3200     |
# | policy_entropy     | 0.609    |
# | total_timesteps    | 16000    |
# | value_loss         | 0.000607 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.503    |
# | fps                | 200      |
# | nupdates           | 3300     |
# | policy_entropy     | 0.677    |
# | total_timesteps    | 16500    |
# | value_loss         | 0.0451   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.9     |
# | fps                | 200      |
# | nupdates           | 3400     |
# | policy_entropy     | 0.562    |
# | total_timesteps    | 17000    |
# | value_loss         | 0.00207  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -5.42    |
# | fps                | 200      |
# | nupdates           | 3500     |
# | policy_entropy     | 0.673    |
# | total_timesteps    | 17500    |
# | value_loss         | 0.00231  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.439    |
# | fps                | 200      |
# | nupdates           | 3600     |
# | policy_entropy     | 0.494    |
# | total_timesteps    | 18000    |
# | value_loss         | 0.0185   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -40.6    |
# | fps                | 200      |
# | nupdates           | 3700     |
# | policy_entropy     | 0.426    |
# | total_timesteps    | 18500    |
# | value_loss         | 0.00256  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.73    |
# | fps                | 200      |
# | nupdates           | 3800     |
# | policy_entropy     | 0.594    |
# | total_timesteps    | 19000    |
# | value_loss         | 0.000309 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.489    |
# | fps                | 200      |
# | nupdates           | 3900     |
# | policy_entropy     | 0.557    |
# | total_timesteps    | 19500    |
# | value_loss         | 0.0533   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.92    |
# | fps                | 200      |
# | nupdates           | 4000     |
# | policy_entropy     | 0.491    |
# | total_timesteps    | 20000    |
# | value_loss         | 0.00111  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.313   |
# | fps                | 200      |
# | nupdates           | 4100     |
# | policy_entropy     | 0.586    |
# | total_timesteps    | 20500    |
# | value_loss         | 0.00425  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.564    |
# | fps                | 200      |
# | nupdates           | 4200     |
# | policy_entropy     | 0.491    |
# | total_timesteps    | 21000    |
# | value_loss         | 0.0665   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0432  |
# | fps                | 199      |
# | nupdates           | 4300     |
# | policy_entropy     | 0.555    |
# | total_timesteps    | 21500    |
# | value_loss         | 0.00577  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -6.07    |
# | fps                | 199      |
# | nupdates           | 4400     |
# | policy_entropy     | 0.496    |
# | total_timesteps    | 22000    |
# | value_loss         | 0.00103  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.547    |
# | fps                | 199      |
# | nupdates           | 4500     |
# | policy_entropy     | 0.451    |
# | total_timesteps    | 22500    |
# | value_loss         | 0.00127  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -3.16    |
# | fps                | 199      |
# | nupdates           | 4600     |
# | policy_entropy     | 0.6      |
# | total_timesteps    | 23000    |
# | value_loss         | 0.0188   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -6.12    |
# | fps                | 199      |
# | nupdates           | 4700     |
# | policy_entropy     | 0.409    |
# | total_timesteps    | 23500    |
# | value_loss         | 0.000787 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.408   |
# | fps                | 199      |
# | nupdates           | 4800     |
# | policy_entropy     | 0.635    |
# | total_timesteps    | 24000    |
# | value_loss         | 0.023    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.248    |
# | fps                | 199      |
# | nupdates           | 4900     |
# | policy_entropy     | 0.673    |
# | total_timesteps    | 24500    |
# | value_loss         | 0.000989 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.91    |
# | fps                | 199      |
# | nupdates           | 5000     |
# | policy_entropy     | 0.544    |
# | total_timesteps    | 25000    |
# | value_loss         | 0.0309   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -5.4     |
# | fps                | 199      |
# | nupdates           | 5100     |
# | policy_entropy     | 0.0693   |
# | total_timesteps    | 25500    |
# | value_loss         | 0.00186  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.664    |
# | fps                | 199      |
# | nupdates           | 5200     |
# | policy_entropy     | 0.627    |
# | total_timesteps    | 26000    |
# | value_loss         | 8.33e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.952   |
# | fps                | 199      |
# | nupdates           | 5300     |
# | policy_entropy     | 0.578    |
# | total_timesteps    | 26500    |
# | value_loss         | 0.0133   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -89.4    |
# | fps                | 199      |
# | nupdates           | 5400     |
# | policy_entropy     | 0.202    |
# | total_timesteps    | 27000    |
# | value_loss         | 0.483    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.67     |
# | fps                | 199      |
# | nupdates           | 5500     |
# | policy_entropy     | 0.592    |
# | total_timesteps    | 27500    |
# | value_loss         | 0.000482 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -5.83    |
# | fps                | 199      |
# | nupdates           | 5600     |
# | policy_entropy     | 0.61     |
# | total_timesteps    | 28000    |
# | value_loss         | 0.00989  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -32.4    |
# | fps                | 199      |
# | nupdates           | 5700     |
# | policy_entropy     | 0.0676   |
# | total_timesteps    | 28500    |
# | value_loss         | 0.00833  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.73    |
# | fps                | 199      |
# | nupdates           | 5800     |
# | policy_entropy     | 0.66     |
# | total_timesteps    | 29000    |
# | value_loss         | 0.000497 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.483   |
# | fps                | 199      |
# | nupdates           | 5900     |
# | policy_entropy     | 0.353    |
# | total_timesteps    | 29500    |
# | value_loss         | 0.00064  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -56.5    |
# | fps                | 199      |
# | nupdates           | 6000     |
# | policy_entropy     | 0.104    |
# | total_timesteps    | 30000    |
# | value_loss         | 0.00123  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.761   |
# | fps                | 199      |
# | nupdates           | 6100     |
# | policy_entropy     | 0.32     |
# | total_timesteps    | 30500    |
# | value_loss         | 0.00378  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0742  |
# | fps                | 199      |
# | nupdates           | 6200     |
# | policy_entropy     | 0.303    |
# | total_timesteps    | 31000    |
# | value_loss         | 0.00229  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -27.9    |
# | fps                | 199      |
# | nupdates           | 6300     |
# | policy_entropy     | 0.0777   |
# | total_timesteps    | 31500    |
# | value_loss         | 0.000898 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -23.8    |
# | fps                | 198      |
# | nupdates           | 6400     |
# | policy_entropy     | 0.577    |
# | total_timesteps    | 32000    |
# | value_loss         | 0.00358  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.4     |
# | fps                | 198      |
# | nupdates           | 6500     |
# | policy_entropy     | 0.377    |
# | total_timesteps    | 32500    |
# | value_loss         | 0.000244 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -31.7    |
# | fps                | 198      |
# | nupdates           | 6600     |
# | policy_entropy     | 0.107    |
# | total_timesteps    | 33000    |
# | value_loss         | 0.00817  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.961    |
# | fps                | 198      |
# | nupdates           | 6700     |
# | policy_entropy     | 0.575    |
# | total_timesteps    | 33500    |
# | value_loss         | 0.00777  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -4       |
# | fps                | 198      |
# | nupdates           | 6800     |
# | policy_entropy     | 0.335    |
# | total_timesteps    | 34000    |
# | value_loss         | 0.00039  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -24.5    |
# | fps                | 198      |
# | nupdates           | 6900     |
# | policy_entropy     | 0.2      |
# | total_timesteps    | 34500    |
# | value_loss         | 0.00114  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.964    |
# | fps                | 198      |
# | nupdates           | 7000     |
# | policy_entropy     | 0.498    |
# | total_timesteps    | 35000    |
# | value_loss         | 0.0079   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.231   |
# | fps                | 198      |
# | nupdates           | 7100     |
# | policy_entropy     | 0.128    |
# | total_timesteps    | 35500    |
# | value_loss         | 0.000765 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.1     |
# | fps                | 198      |
# | nupdates           | 7200     |
# | policy_entropy     | 0.211    |
# | total_timesteps    | 36000    |
# | value_loss         | 0.0102   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.951    |
# | fps                | 198      |
# | nupdates           | 7300     |
# | policy_entropy     | 0.483    |
# | total_timesteps    | 36500    |
# | value_loss         | 0.0109   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.221    |
# | fps                | 198      |
# | nupdates           | 7400     |
# | policy_entropy     | 0.173    |
# | total_timesteps    | 37000    |
# | value_loss         | 0.00116  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.816    |
# | fps                | 198      |
# | nupdates           | 7500     |
# | policy_entropy     | 0.194    |
# | total_timesteps    | 37500    |
# | value_loss         | 0.0173   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.664    |
# | fps                | 198      |
# | nupdates           | 7600     |
# | policy_entropy     | 0.358    |
# | total_timesteps    | 38000    |
# | value_loss         | 0.189    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.21    |
# | fps                | 198      |
# | nupdates           | 7700     |
# | policy_entropy     | 0.28     |
# | total_timesteps    | 38500    |
# | value_loss         | 0.000222 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.896    |
# | fps                | 199      |
# | nupdates           | 7800     |
# | policy_entropy     | 0.231    |
# | total_timesteps    | 39000    |
# | value_loss         | 0.0165   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.506    |
# | fps                | 199      |
# | nupdates           | 7900     |
# | policy_entropy     | 0.345    |
# | total_timesteps    | 39500    |
# | value_loss         | 0.0442   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.82    |
# | fps                | 199      |
# | nupdates           | 8000     |
# | policy_entropy     | 0.464    |
# | total_timesteps    | 40000    |
# | value_loss         | 0.00128  |
# ---------------------------------

# %%
#Testing the AE_powered RL model and viewing its profit
env = environment(df=baseline_env_df, window_size=wind_size, frame_bound=(100,150))
env.seed(2021)
obs = env.reset()
while True: 
    obs = obs[np.newaxis, ...]
    action, _states = model_20.predict(obs)
    obs, rewards, done, info = env.step(action)
    if done:
        print("The total profit after 50 days is ",info['total_profit'])
        break
# Out:
# The total profit after 50 days is  0.9790724958748944

# %% [markdown]
# It can be seen that the baseline model loses money (about 2%), while the AE-powered trading bot more than doubles the initial investment. From the performance of the trading bots, the autoencoder proves effective in reducing noise while extracting important trends from the dataframe of financial indicators. Refining the autoencoder through adopting a different architecture and using hyperparameter tuning may increase performance, and this will be the focus of a future project of mine.
